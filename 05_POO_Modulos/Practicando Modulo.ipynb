# %%
#PROBANDO LA CLASE ATOMO
class Atom:
    atomo=""
    posicionX=0
    posicionY=0
    posicionZ=0
    r=[]
    def __init__(self, atomo="", posicionX=0,posicionY=0,posicionZ=0):
        self.atomo=atomo
        self.posicionX=posicionX
        self.posicionY=posicionY
        self.posicionZ=posicionZ
    def info(self):
        print("--info--")
        print(self.atomo,self.posicionX,self.posicionY,self.posicionZ)
    def distancia(self,atomo2):
        self.atomo2 = atomo2
        num1 = self.atomo2.posicionX - self.posicionX
        num1 = num1**2
        num2 = self.atomo2.posicionY - self.posicionY
        num2 = num2**2
        resul = num1+num2
        resul = resul**0.5
        print(resul)
        
ejem=[]
atomo1 = Atom("a",-1.214922,-0.600875,4.908394)
atomo2 = Atom("b",-0.366988,-1.363569,3.706242)
print("calcular la distancia de 2 puntos:")
atomo1.distancia(atomo2)

#antes:
# ejem.append(atomo1)
# ejem.append(atomo2)
#ahora:
ejem.append(Atom("a",7,4,3))
ejem.append(Atom("b",1,2,8))

print("asi si")
for i in ejem:
    i.info()
print("asi no")
print(ejem)
# atomo1.info()
# Out:
# calcular la distancia de 2 puntos:
# 1.1404798139344685
# asi si
# --info--
# a 7 4 3
# --info--
# b 1 2 8
# asi no
# [<__main__.Atom object at 0x0000025285953670>, <__main__.Atom object at 0x00000252859532B0>]

# %%
#EJER 1 BIEN
class Atom:
    atomo=""
    posicionX=0
    posicionY=0
    posicionZ=0
    def __init__(self, atomo, posicionX,posicionY,posicionZ):
        self.atomo=atomo
        self.posicionX=posicionX
        self.posicionY=posicionY
        self.posicionZ=posicionZ
    def info(self):
        print(self.atomo,self.posicionX,self.posicionY,self.posicionZ)
    def distancia(self,atomo2):
        pass

archivo = "C60.xyz"
text = open(archivo).readlines()

step=[]
step2=[]
step3=[]
dinamic=[]

# for i in range(2,62):
# #     print(text[i+2].split())
# #     step1.append(text[i+2].split())
#     step.append(Atom(text[i].split()[0],text[i].split()[1],text[i].split()[2],text[i].split()[3])) #asi dentro de atomo le meto los steps
# dinamic.append(step)
# for i in range(64,124): #es 64 y NO 65
#     step2.append(Atom(text[i].split()[0],text[i].split()[1],text[i].split()[2],text[i].split()[3])) 
# dinamic.append(step2)
# for i in range(126,186): 
#     step3.append(Atom(text[i].split()[0],text[i].split()[1],text[i].split()[2],text[i].split()[3])) 
# dinamic.append(step3)

    
# for i in range(2,62):
#     step.append(Atom(text[i].split()[0],text[i].split()[1],text[i].split()[2],text[i].split()[3])) #asi dentro de atomo le meto los steps
# dinamic.append(step)
# for i in range(64,124):
#     step.append(Atom(text[i].split()[0],text[i].split()[1],text[i].split()[2],text[i].split()[3])) 
# dinamic.append(step)
# for i in range(126,186): 
#     step.append(Atom(text[i].split()[0],text[i].split()[1],text[i].split()[2],text[i].split()[3]))
# dinamic.append(step)
    
a=2
b=62
for i in range(5): #porque hay 188 steps
    step=[]
    for i in range(a,b):
        step.append(Atom(text[i].split()[0],text[i].split()[1],text[i].split()[2],text[i].split()[3])) #asi dentro de atomo le meto los steps
    dinamic.append(step)
    a+=62
    b+=62

for i in dinamic:
    print("step",dinamic.index(i)+1)
    for j in range(60):
        i[j].info()
# Out:
# step 1
# C -1.214922 -0.600875 4.908394
# C -0.366988 -1.363569 3.706242
# C 1.002807 -0.919405 3.702649
# C 1.001576 0.121535 4.902491
# C -0.368563 0.164969 5.906441
# C 1.574459 -2.571027 1.818916
# C 2.333194 -2.567689 0.594793
# C 3.172470 -1.423953 0.599588
# C 2.944865 -0.685120 1.818843
# C 1.952791 -1.406881 2.775272
# C 2.777587 -1.171696 -1.819862
# C 2.402845 0.001707 -2.559209
# C 2.783697 1.165705 -1.799296
# C 3.398280 0.718727 -0.584637
# C 3.413152 -0.701658 -0.569599
# C 0.741216 2.278719 -2.554304
# C -2.312431 -2.574565 -0.568509
# C -3.160902 -1.410879 -0.567432
# C -2.928580 -0.690653 -1.793585
# C -1.936931 -1.409431 -2.551095
# C -1.557167 -2.573081 -1.794173
# C -3.162763 1.408055 -0.567700
# C -2.316552 2.573176 -0.568995
# C -1.560157 2.572562 -1.795256
# C -1.939711 1.407950 -2.550964
# C -2.930113 0.687456 -1.793087
# C 0.364915 3.442682 -0.573082
# C 1.733475 2.999228 -0.576600
# C 1.969389 2.277266 -1.800251
# C -0.248905 2.998275 -1.795555
# ...

# %%
from modulo.dinamic import *

dinamic = obtenerDinamic()

#obtener la distancia de 2 puntos
print("distancias:")
# dinamic[0][4].distancia(dinamic[0][41])
# dinamic[1][4].distancia(dinamic[1][41])
# dinamic[2][4].distancia(dinamic[2][41])
# dinamic[3][4].distancia(dinamic[3][41])
for i in range(188):
    dinamic[i][4].distancia(dinamic[i][41])
# Out:
# distancias:
# 3.904501
# 3.901908
# 3.894210
# 3.881948
# 3.867060
# 3.854700
# 3.850617
# 3.857386
# 3.868557
# 3.875228
# 3.872485
# 3.866309
# 3.850146
# 3.827342
# 3.804163
# 3.788530
# 3.790022
# 3.794563
# 3.798594
# 3.797567
# 3.788946
# 3.784663
# 3.773080
# 3.756825
# 3.738882
# 3.718937
# 3.719394
# 3.716875
# 3.708280
# 3.691488
# 3.665482
# 3.661208
# 3.648529
# 3.629208
# 3.606579
# 3.584511
# 3.586143
# 3.587073
# 3.583203
# 3.571565
# 3.550867
# 3.546223
# 3.532938
# 3.512765
# 3.488800
# 3.464234
# 3.464404
# 3.462455
# 3.455152
# 3.440081
# 3.416075
# 3.383042
# 3.341805
# 3.294063
# 3.241919
# 3.186399
# 3.126656
# 3.061665
# 2.991656
# 2.917467
# 2.915250
# 2.908208
# 2.896808
# 2.881676
# 2.863276
# 2.861484
# 2.855492
# 2.843720
# 2.824158
# 2.794893
# 2.754235
# 2.700621
# 2.632436
# 2.547855
# 2.444185
# 2.318027
# 2.165658
# 1.983898
# 1.770927
# 1.528809
# 1.274406
# 1.082374
# 1.122046
# 1.180237
# 1.346380
# 1.522952
# 1.665115
# 1.755547
# 1.720848
# ...
